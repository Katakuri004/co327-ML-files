# %%
# Perform NumPy operation 2: Standard Deviation of MedInc
medinc_std = np.std(california_array[:, california_df.columns.get_loc('MedInc')])
print(f"Standard Deviation of MedInc: {medinc_std}")
# Out:
# Standard Deviation of MedInc: 1.8997756945748738

# %% [markdown]
# ## Numpy operations
#
# ### Subtask:
# Perform 5 different operations on the dataset using NumPy.

# %%
# Perform NumPy operation 3: Minimum of HouseAge
houseage_min = np.min(california_array[:, california_df.columns.get_loc('HouseAge')])
print(f"Minimum of HouseAge: {houseage_min}")
# Out:
# Minimum of HouseAge: 1.0

# %%
# Perform NumPy operation 4: Maximum of HouseAge
houseage_max = np.max(california_array[:, california_df.columns.get_loc('HouseAge')])
print(f"Maximum of HouseAge: {houseage_max}")
# Out:
# Maximum of HouseAge: 52.0

# %%
# Perform NumPy operation 5: Sum of Population
population_sum = np.sum(california_array[:, california_df.columns.get_loc('Population')])
print(f"Sum of Population: {population_sum}")
# Out:
# Sum of Population: 29421840.0

# %% [markdown]
# ## Pandas operations
#
# ### Subtask:
# Perform 5 different operations on the dataset using Pandas.

# %%
# Perform Pandas operation 1: Mean of MedInc
medinc_mean_pd = california_df['MedInc'].mean()
print(f"Mean of MedInc (Pandas): {medinc_mean_pd}")
# Out:
# Mean of MedInc (Pandas): 3.8706710029069766

# %%
# Perform Pandas operation 2: Standard Deviation of MedInc
medinc_std_pd = california_df['MedInc'].std()
print(f"Standard Deviation of MedInc (Pandas): {medinc_std_pd}")
# Out:
# Standard Deviation of MedInc (Pandas): 1.8998217179452732

# %%
# Perform Pandas operation 3: Minimum of HouseAge
houseage_min_pd = california_df['HouseAge'].min()
print(f"Minimum of HouseAge (Pandas): {houseage_min_pd}")
# Out:
# Minimum of HouseAge (Pandas): 1.0

# %%
# Perform Pandas operation 4: Maximum of HouseAge
houseage_max_pd = california_df['HouseAge'].max()
print(f"Maximum of HouseAge (Pandas): {houseage_max_pd}")
# Out:
# Maximum of HouseAge (Pandas): 52.0

# %%
# Perform Pandas operation 5: Sum of Population
population_sum_pd = california_df['Population'].sum()
print(f"Sum of Population (Pandas): {population_sum_pd}")
# Out:
# Sum of Population (Pandas): 29421840.0

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Visualization 1: Histogram of Median Income
plt.figure(figsize=(10, 6))
sns.histplot(california_df['MedInc'], bins=50, kde=True)
plt.title('Distribution of Median Income')
plt.xlabel('Median Income')
plt.ylabel('Frequency')
plt.show()

# %%
# Visualization 2: Scatter plot of Median Income vs Median House Value
plt.figure(figsize=(10, 6))
sns.scatterplot(x='MedInc', y='MedHouseVal', data=california_df, alpha=0.6)
plt.title('Median Income vs Median House Value')
plt.xlabel('Median Income')
plt.ylabel('Median House Value')
plt.show()

# %%
# Visualization 3: Box plot of House Age by Median House Value
plt.figure(figsize=(10, 6))
sns.boxplot(x='HouseAge', data=california_df)
plt.title('Distribution of House Age')
plt.xlabel('House Age')
plt.show()

# %%
# Visualization 4: Heatmap of correlations
plt.figure(figsize=(10, 8))
sns.heatmap(california_df.corr(), annot=True, cmap='coolwarm', fmt=".2f")
plt.title('Correlation Heatmap of California Housing Dataset')
plt.show()
